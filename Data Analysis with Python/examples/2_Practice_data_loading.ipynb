# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Practice Lab: Importing Dataset - Laptops Pricing**
#
# Estimated time needed: **20** minutes
#
# In this lab, you will practice the process of loading and drawing basic insights on a dataset as learnt through the module. You are being provided with a fresh dataset on 'Laptop Pricing' which will be used for all the practice labs throughout the course.

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Import a dataset from a CSV file to a Pandas dataframe
#  - Develop some basic insights about the dataset

# %% [markdown]
# # Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# * `skillsnetwork` for downloading the daataset
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.

# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
# Note: The original implementation used `pyodide`, which is only available in JupyterLite.
# For local Jupyter (Notebook / Lab), use the synchronous downloader in the next cell
# or read the CSV directly with `pd.read_csv(file_path)`.
# This placeholder keeps the notebook compatible across environments.
pass

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_base.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
# For local Jupyter: attempt to read directly from URL, otherwise download with requests
import os
try:
    # try reading directly from the URL into pandas
    df = pd.read_csv(file_path)
    file_name = None
    print('Loaded dataframe directly from URL')
except Exception:
    if not os.path.exists('laptops.csv'):
        try:
            import requests
            r = requests.get(file_path)
            r.raise_for_status()
            with open('laptops.csv','wb') as f:
                f.write(r.content)
            print('Downloaded laptops.csv')
        except Exception as e:
            print('Could not download file:', e)
    file_name = 'laptops.csv'
    df = pd.read_csv(file_name)
# Out:
# Loaded dataframe directly from URL

# %%
# Load dataframe from local file if `file_name` was set by the downloader;
# otherwise the previous cell already loaded `df` from the URL.
if 'file_name' in globals() and file_name:
    df = pd.read_csv(file_name)
else:
    # df should already be loaded from the URL in the previous cell
    pass

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface. While working on the downloaded version of this notebook on their local machines, the learners can simply **skip the steps above**, and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_base.csv"
#df = pd.read_csv(filepath, header=None)

# %% [markdown]
# <h1> Task #1: </h1>
# <h3>Load the dataset to a pandas dataframe named 'df'</h3>
# Print the first 5 entries of the dataset to confirm loading.

# %%
# Load dataframe for Task 1 and print the first 5 rows.
# If `df` already exists (from the downloader cell), use it; otherwise try to read from the URL or local file.
if 'df' not in globals():
    try:
        df = pd.read_csv(file_path, header=None)
        print('Loaded df from URL with header=None')
    except Exception:
        try:
            df = pd.read_csv('laptops.csv', header=None)
            print('Loaded df from local laptops.csv with header=None')
        except Exception as e:
            raise RuntimeError('Could not load dataframe: ' + str(e))
# Display first 5 rows
print(df.head())
# Out:
#    Acer  4  IPS Panel  2  1  5   35.56  1.6  8  256 1.6.1   978
# 0  Dell  3    Full HD  1  1  3  39.624  2.0  4  256   2.2   634
# 1  Dell  3    Full HD  1  1  7  39.624  2.7  8  256   2.2   946
# 2  Dell  4  IPS Panel  2  1  5  33.782  1.6  8  128  1.22  1244
# 3    HP  4    Full HD  2  1  7  39.624  1.8  8  256  1.91   837
# 4  Dell  3    Full HD  1  1  5  39.624  1.6  8  256   2.2  1016

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# df = pd.read_csv(file_name, header=None)
# print(df.head())
# ```
# </details>

# %% [markdown]
# <h1> Task #2: </h1>
# <h3>Add headers to the dataframe</h3>
# The headers for the dataset, in sequence, are "Manufacturer", "Category", "Screen", "GPU", "OS", "CPU_core",
# "Screen_Size_inch", "CPU_frequency", "RAM_GB", "Storage_GB_SSD", "Weight_kg" and "Price".
#
# Confirm insertion by printing the first 10 rows of the dataset.

# %%
# Add headers to the dataframe and print first 10 rows.
headers = ["Manufacturer", "Category", "Screen", "GPU", "OS", "CPU_core", "Screen_Size_inch", "CPU_frequency", "RAM_GB", "Storage_GB_SSD", "Weight_kg", "Price"]
if 'df' in globals():
    # assign headers (ensure column count matches)
    if df.shape[1] == len(headers):
        df.columns = headers
    else:
        # if header count mismatch, still attempt assignment for first min cols
        n = min(df.shape[1], len(headers))
        df.columns = headers[:n] + list(df.columns[n:])
    print(df.head(10))
else:
    raise RuntimeError('Dataframe `df` not found. Run Task 1 first to load the data.')
# Out:
#   Manufacturer  Category     Screen  GPU  OS  CPU_core Screen_Size_inch  \
# 0         Dell         3    Full HD    1   1         3           39.624
# 1         Dell         3    Full HD    1   1         7           39.624
# 2         Dell         4  IPS Panel    2   1         5           33.782
# 3           HP         4    Full HD    2   1         7           39.624
# 4         Dell         3    Full HD    1   1         5           39.624
# 5           HP         3    Full HD    3   1         5           39.624
# 6         Acer         3  IPS Panel    2   1         5             38.1
# 7         Dell         3    Full HD    1   1         5           39.624
# 8         Acer         3  IPS Panel    3   1         7             38.1
# 9         Dell         3    Full HD    1   1         7           39.624
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD Weight_kg  Price
# 0            2.0       4             256       2.2    634
# 1            2.7       8             256       2.2    946
# 2            1.6       8             128      1.22   1244
# 3            1.8       8             256      1.91    837
# 4            1.6       8             256       2.2   1016
# 5            1.6       8             256       2.1   1117
# 6            1.6       4             256       2.2    866
# 7            2.5       4             256       2.3    812
# 8            1.8       8             256       2.2   1068
# 9            1.8       8             256      2.13    975

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# # create headers list
# headers = ["Manufacturer", "Category", "Screen", "GPU", "OS", "CPU_core", "Screen_Size_inch", "CPU_frequency", "RAM_GB", "Storage_GB_SSD", "Weight_kg", "Price"]
# df.columns = headers
# print(df.head(10))
# ```
# </details>

# %% [markdown]
# <h1> Task #3: </h1>
# <h3>Replace '?' with 'NaN'</h3>
# Replace the '?' entries in the dataset with NaN value, recevied from the Numpy package.

# %%
# Replace '?' entries with NaN from numpy
if 'df' in globals():
    df.replace('?', np.nan, inplace=True)
    print("Replaced '?' with NaN. Showing sample rows:\n")
    print(df.head())
else:
    raise RuntimeError('Dataframe `df` not found. Run Task 1 first to load the data.')
# Out:
# Replaced '?' with NaN. Showing sample rows:
#
#   Manufacturer  Category     Screen  GPU  OS  CPU_core Screen_Size_inch  \
# 0         Dell         3    Full HD    1   1         3           39.624
# 1         Dell         3    Full HD    1   1         7           39.624
# 2         Dell         4  IPS Panel    2   1         5           33.782
# 3           HP         4    Full HD    2   1         7           39.624
# 4         Dell         3    Full HD    1   1         5           39.624
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD Weight_kg  Price
# 0            2.0       4             256       2.2    634
# 1            2.7       8             256       2.2    946
# 2            1.6       8             128      1.22   1244
# 3            1.8       8             256      1.91    837
# 4            1.6       8             256       2.2   1016

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# df.replace('?',np.nan, inplace = True)
# ```
# </details>

# %% [markdown]
# <h1> Task #4: </h1>
# <h3>Print the data types of the dataframe columns</h3>
# Make a note of the data types of the different columns of the dataset.

# %%
# Print data types of dataframe columns for Task 4
if 'df' in globals():
    print(df.dtypes)
else:
    raise RuntimeError('Dataframe `df` not found. Run Task 1 first to load the data.')
# Out:
# Manufacturer         object
# Category              int64
# Screen               object
# GPU                   int64
# OS                    int64
# CPU_core              int64
# Screen_Size_inch     object
# CPU_frequency       float64
# RAM_GB                int64
# Storage_GB_SSD        int64
# Weight_kg            object
# Price                 int64
# dtype: object

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# print(df.dtypes)
# ```
# </details>

# %% [markdown]
# <h1> Task #5: </h1>
# <h3>Print the statistical description of the dataset, including that of 'object' data types.</h3>

# %%
# Print statistical description of the dataset (include object dtypes) for Task 5
if 'df' in globals():
    print(df.describe(include='all'))
else:
    raise RuntimeError('Dataframe `df` not found. Run Task 1 first to load the data.')
# Out:
#        Manufacturer    Category   Screen         GPU          OS    CPU_core  \
# count           237  237.000000      237  237.000000  237.000000  237.000000
# unique           11         NaN        2         NaN         NaN         NaN
# top            Dell         NaN  Full HD         NaN         NaN         NaN
# freq             71         NaN      161         NaN         NaN         NaN
# mean            NaN    3.202532      NaN    2.151899    1.059072    5.632911
# std             NaN    0.776450      NaN    0.639556    0.236258    1.243736
# min             NaN    1.000000      NaN    1.000000    1.000000    3.000000
# 25%             NaN    3.000000      NaN    2.000000    1.000000    5.000000
# 50%             NaN    3.000000      NaN    2.000000    1.000000    5.000000
# 75%             NaN    4.000000      NaN    3.000000    1.000000    7.000000
# max             NaN    5.000000      NaN    3.000000    2.000000    7.000000
#
#        Screen_Size_inch  CPU_frequency      RAM_GB  Storage_GB_SSD Weight_kg  \
# count               233     237.000000  237.000000      237.000000       232
# unique                9            NaN         NaN             NaN        77
# top              39.624            NaN         NaN             NaN       2.2
# freq                 89            NaN         NaN             NaN        21
# mean                NaN       2.363291    7.881857      245.738397       NaN
# std                 NaN       0.409271    2.487845       34.832516       NaN
# min                 NaN       1.200000    4.000000      128.000000       NaN
# 25%                 NaN       2.000000    8.000000      256.000000       NaN
# 50%                 NaN       2.500000    8.000000      256.000000       NaN
# 75%                 NaN       2.700000    8.000000      256.000000       NaN
# max                 NaN       2.900000   16.000000      256.000000       NaN
#
#               Price
# count    237.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    1464.388186
# std      574.956374
# min      527.000000
# 25%     1068.000000
# 50%     1333.000000
# 75%     1777.000000
# max     3810.000000

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# print(df.describe(include='all'))
# ```
# </details>

# %% [markdown]
# <h1> Task #6: </h1>
# <h3>Print the summary information of the dataset.</h3>

# %%
# Print summary information of the dataset for Task 6
if 'df' in globals():
    # df.info() prints to stdout and returns None; show a header for clarity
    print('Dataframe info:')
    df.info()
else:
    raise RuntimeError('Dataframe `df` not found. Run Task 1 first to load the data.')
# Out:
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      237 non-null    object
#  1   Category          237 non-null    int64
#  2   Screen            237 non-null    object
#  3   GPU               237 non-null    int64
#  4   OS                237 non-null    int64
#  5   CPU_core          237 non-null    int64
#  6   Screen_Size_inch  233 non-null    object
#  7   CPU_frequency     237 non-null    float64
#  8   RAM_GB            237 non-null    int64
#  9   Storage_GB_SSD    237 non-null    int64
#  10  Weight_kg         232 non-null    object
#  11  Price             237 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 22.3+ KB

# %% [markdown]
# <details><summary>Click here for solution</summary>
#
# ```python
# print(df.info())
# ```
# </details>

# %% [markdown]
# ---

# %% [markdown]
# # Congratulations! You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# [Abhishek Gagneja](https://www.coursera.org/instructor/~129186572)
#
# [Vicky Kuo](https://author.skills.network/instructors/vicky_kuo)

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-09-15|0.1|Abhishek Gagneja|Initial Version Created|
# |2023-09-18|0.2|Vicky Kuo|Reviewed and Revised|--!>
